# %% [markdown]
# # Кратко об этом исследовании
# Данные из Остинского центра животных, то есть приюта, -- с 1 октября 2013 по **март 2016**.
#
# ### Цель
#
# Требуется предсказать судьбу каждого животного по данным о нём сведениям. По сути, обычная задача категоризации. Классы: Adoption, Died, Euthanasia, Return to owner, Transfer.
#
# Все классы считаем одинаково важными все зависимости от представленности в выборке. Качество предсказаний оценивается поэтому с помощью macro-averaged F1 score.
#
# ---
#
# **Задание**
#
# Пользоваться в точности предложенной в этом шаблоне схемой необязательно, но в этом ноутбуке должен быть
# - внятный и чистый,
# - прокомментированный,
# - воспроизводимый (зафиксируйте все random seeds, которые возможно),
# - мотивированный
# **код**, который **генерирует ваше лучшее решение**.
#
# А также пока **неформальный отчёт** о проделанной работе.
#
#
# ### Методы
#
# Я процессе исследования я пытался использовать разные модели: Логистическую регрессию, решающие деревья, случайный лес, бустинги.
#
# Я пробовал разделять датасет отдельно на кошек и собак, но большого результата это не дало.
#
# Были попытки предобрабатывать данные с помощью SVD, но также не получил какого-то улучшения.
#
#
# ### Результаты
#
# Лучшие результаты у меня показали решающие деревья и на самом деле очень удивительно, что эти результаты достигнуты при достаточно большом количестве деревьев.
#
# Дальше в ноутбуке описано, как я предобрабатываю данные и какие параметры использую.
#
# ---
# ---
# ---

# %% [markdown]
# ## Конфиги и константы

# %%
OUTCOME2LABEL = {"Adoption": 0,
                 "Transfer": 1,
                 "Return_to_owner": 2,
                 "Euthanasia": 3,
                 "Died": 4
                 }
LABEL2OUTCOME = {v: k for k, v in OUTCOME2LABEL.items()}

score = "f1_macro"

FOLD_K = 4

# %% [markdown]
# ## Библиотеки

# %%
import pandas as pd
import numpy as np
import eli5

from scipy import sparse
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier

# %%
df_train = pd.read_csv("train.csv", encoding="utf-8")
df_test = pd.read_csv("test.csv", encoding="utf-8")
df_train.head(5)
# Out:
#       Name SexuponOutcome AnimalType AgeuponOutcome                    Breed  \
# 0    Socks  Neutered Male        Cat       2 months   Domestic Shorthair Mix
# 1     Vera  Intact Female        Cat        1 month   Domestic Shorthair Mix
# 2  Biscuit  Neutered Male        Dog       3 months  Chihuahua Shorthair Mix
# 3   Kitten  Spayed Female        Cat        2 years   Domestic Shorthair Mix
# 4      NaN  Neutered Male        Cat       2 months   Domestic Shorthair Mix
#
#           Color             DateTime  Outcome  ID
# 0   Black/White  2014-06-11 14:36:00        0   0
# 1  Tortie/White  2014-07-18 08:10:00        3   1
# 2        Yellow  2016-01-02 17:28:00        2   2
# 3        Calico  2014-02-19 17:27:00        0   3
# 4  Orange Tabby  2014-07-21 17:34:00        0   4

# %% [markdown]
# ### Подготовка признаков
#
# #### Даты
#
# Даты преобразуем в количество дней от даты поступления.

# %%
def date2numbers(date: str):
    year, month, date = map(int, date.split(' ')[0].split('-')[:3])
    return (2016 - year) * 24 * 30 + month * 30 + date


def pandas_dates2number(date_series: pd.Series):
    return date_series.apply(date2numbers)


pandas_dates2number(df_train["DateTime"])
# Out:
# 0        1631
# 1        1668
# 2          32
# 3        1519
# 4        1671
#          ...
# 18705     854
# 18706    2488
# 18707    1805
# 18708    1649
# 18709    2544
# Name: DateTime, Length: 18710, dtype: int64

# %% [markdown]
# #### Возраст
#
# Возраст преобразуем просто в количество дней. Отсутствующие значение меняем на средние.

# %%
def pandas_ages2number(date_series: pd.Series):
    def transform_age_line(age):
        if type(age) is not str:
            return float('nan')
        num, time = age.split()
        return int(num) * (("month" in time) + ("year" in time) * 12)
    numbers_df = date_series.apply(transform_age_line)
    mean = numbers_df.mean()
    numbers_df = numbers_df.fillna(value=mean)
    return numbers_df


pandas_ages2number(pd.Series([float('nan'), "2 years", "3 month"]))
# Out:
# 0    13.5
# 1    24.0
# 2     3.0
# dtype: float64

# %% [markdown]
# #### Цвета и породы
#
# Повторяющихся категорий много, так что можно закодировать их и так, однако **некоторые из них можно и растащить на части**

# %%
df_train["Color"].value_counts()
# Out:
# Black/White                1955
# Black                      1594
# Brown Tabby                1122
# Brown Tabby/White           680
# White                       649
#                            ...
# Tricolor/Calico               1
# Blue Tabby/Orange             1
# Black Smoke/Brown Tabby       1
# Lynx Point/Brown Tabby        1
# Liver Tick/White              1
# Name: Color, Length: 326, dtype: int64

# %% [markdown]
# #####  CountVectorizer

# %%
vectorizer = CountVectorizer()
vectorized_color = vectorizer.fit_transform(df_train["Color"])

print(vectorizer.vocabulary_)

vectorized_color
# Out:
# {'black': 2, 'white': 34, 'tortie': 32, 'yellow': 35, 'calico': 7, 'orange': 18, 'tabby': 27, 'tan': 28, 'buff': 6, 'brown': 5, 'brindle': 4, 'chocolate': 8, 'blue': 3, 'tricolor': 33, 'red': 21, 'torbie': 31, 'sable': 23, 'cream': 9, 'merle': 17, 'gray': 13, 'lynx': 16, 'point': 20, 'flame': 11, 'lilac': 14, 'gold': 12, 'seal': 24, 'silver': 25, 'smoke': 26, 'fawn': 10, 'tick': 29, 'apricot': 1, 'liver': 15, 'tiger': 30, 'agouti': 0, 'pink': 19, 'ruddy': 22}
# <18710x36 sparse matrix of type '<class 'numpy.int64'>'
# 	with 33576 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Breed
# Если мы посмотрим на количества определенных пород, то увидим, что у нас несколько пород встречаются довольно часто, а остальные все менее редко.
# Также заметим, что у нас некоторые породы встречаются всего 1 раз, поэтому мы можем ожидать, что на тесте мы увидим новые породы.

# %%
df_train.Breed.value_counts()
# Out:
# Domestic Shorthair Mix            6153
# Pit Bull Mix                      1318
# Chihuahua Shorthair Mix           1225
# Labrador Retriever Mix             984
# Domestic Medium Hair Mix           590
#                                   ...
# Cairn Terrier/Miniature Poodle       1
# Jack Russell Terrier/Pointer         1
# Whippet/Australian Kelpie            1
# Miniature Schnauzer/Shih Tzu         1
# Great Dane/Pit Bull                  1
# Name: Breed, Length: 1145, dtype: int64

# %% [markdown]
# Было принято решение разделить их по классам, в которых будет не менее 500 экземпляров на трейне, если встретим 0, то дадим им метку 0.
#
# (Изначально я пытался использовать CountVectorizer и OneHotEncoder, но они не давали такого хорошего результата, скорее всего из-за того, что если мы в дереве решений сплитим, по какому-то из сгенерированных ими признаков, мы будем использовать слишком мало информации, например принадлежит ли он одной конкретной породе или есть ли в названии породы какое-то слово, кажется, что делить так не очень эффективно.)

# %%
breeds = df_train.Breed.value_counts().to_dict()

my_breeds_encoder = {}

current_sum = 0

for key, value in breeds.items():
    current_sum += value
    if current_sum > 500:
        current_sum = 0
        for prev in my_breeds_encoder.keys():
            my_breeds_encoder[prev] += 1
    my_breeds_encoder[key] = 1

my_breeds_encoder
# Out:
# {'Domestic Shorthair Mix': 20,
#  'Pit Bull Mix': 19,
#  'Chihuahua Shorthair Mix': 18,
#  'Labrador Retriever Mix': 17,
#  'Domestic Medium Hair Mix': 16,
#  'German Shepherd Mix': 16,
#  'Domestic Longhair Mix': 15,
#  'Siamese Mix': 15,
#  'Australian Cattle Dog Mix': 14,
#  'Dachshund Mix': 14,
#  'Boxer Mix': 14,
#  'Miniature Poodle Mix': 13,
#  'Border Collie Mix': 13,
#  'Rat Terrier Mix': 13,
#  'Catahoula Mix': 13,
#  'Australian Shepherd Mix': 12,
#  'Jack Russell Terrier Mix': 12,
#  'Yorkshire Terrier Mix': 12,
#  'Miniature Schnauzer Mix': 12,
#  'Siberian Husky Mix': 12,
#  'Chihuahua Longhair Mix': 12,
#  'Domestic Shorthair': 11,
#  'Beagle Mix': 11,
#  'Rottweiler Mix': 11,
#  'American Bulldog Mix': 11,
#  'Pointer Mix': 11,
#  'Shih Tzu Mix': 11,
#  'Australian Kelpie Mix': 11,
#  'Chihuahua Shorthair/Dachshund': 10,
#  'American Staffordshire Terrier Mix': 10,
#  'Staffordshire Mix': 10,
#  'Cairn Terrier Mix': 10,
#  'Chihuahua Shorthair': 10,
#  'Great Pyrenees Mix': 10,
#  'German Shepherd': 10,
#  'Labrador Retriever/Pit Bull': 10,
#  'Anatol Shepherd Mix': 10,
#  'Snowshoe Mix': 9,
#  'Pit Bull': 9,
#  'Labrador Retriever': 9,
#  'Dachshund/Chihuahua Shorthair': 9,
#  'Plott Hound Mix': 9,
#  'German Shepherd/Labrador Retriever': 9,
#  'Golden Retriever Mix': 9,
#  'American Pit Bull Terrier Mix': 9,
#  'Chow Chow Mix': 9,
#  'Labrador Retriever/German Shepherd': 9,
#  'Miniature Pinscher Mix': 9,
#  'Pug Mix': 8,
#  'Black Mouth Cur Mix': 8,
#  'Shih Tzu': 8,
#  'Cocker Spaniel Mix': 8,
#  'Cardigan Welsh Corgi Mix': 8,
#  'Lhasa Apso Mix': 8,
#  'Maltese Mix': 8,
#  'Manx Mix': 8,
#  'Queensland Heeler Mix': 8,
#  'Miniature Schnauzer/Miniature Poodle': 8,
#  'Maine Coon Mix': 8,
#  'Doberman Pinsch Mix': 8,
#  'Boston Terrier Mix': 8,
#  'Domestic Medium Hair': 8,
#  'Basset Hound Mix': 8,
#  'Dachshund': 8,
#  'Labrador Retriever/Border Collie': 7,
#  'Blue Lacy Mix': 7,
#  'Toy Poodle Mix': 7,
#  'Carolina Dog Mix': 7,
#  'Manchester Terrier Mix': 7,
#  'Dachshund Longhair Mix': 7,
#  'Pomeranian Mix': 7,
#  'Rottweiler': 7,
#  'Russian Blue Mix': 7,
#  'Australian Cattle Dog/Labrador Retriever': 7,
#  'Pit Bull/Labrador Retriever': 7,
#  'Maltese/Miniature Poodle': 7,
#  'Flat Coat Retriever Mix': 7,
#  'Labrador Retriever/Australian Cattle Dog': 7,
#  'Siberian Husky': 7,
#  'Border Collie/Labrador Retriever': 7,
#  'Rhod Ridgeback Mix': 7,
#  'Boxer': 7,
#  'Collie Smooth Mix': 7,
#  'Pekingese Mix': 7,
#  'Chinese Sharpei Mix': 7,
#  'Chihuahua Shorthair/Jack Russell Terrier': 7,
#  'Australian Cattle Dog': 6,
#  'Border Terrier Mix': 6,
#  'Pug': 6,
#  'Maltese': 6,
#  'Siamese': 6,
#  'Labrador Retriever/Boxer': 6,
#  'Cocker Spaniel': 6,
#  'Pug/Chihuahua Shorthair': 6,
#  'Black/Tan Hound Mix': 6,
#  'Miniature Schnauzer': 6,
#  'Miniature Poodle/Miniature Schnauzer': 6,
#  'Dachshund Wirehair Mix': 6,
#  'Rat Terrier/Chihuahua Shorthair': 6,
#  'Boxer/Pit Bull': 6,
#  'Labrador Retriever/Pointer': 6,
#  'Norfolk Terrier Mix': 6,
#  'Bull Terrier Mix': 6,
#  'Soft Coated Wheaten Terrier Mix': 6,
#  'Shetland Sheepdog Mix': 6,
#  'English Bulldog Mix': 6,
#  'Whippet Mix': 6,
#  'Yorkshire Terrier': 6,
#  'Bruss Griffon Mix': 6,
#  'Redbone Hound Mix': 6,
#  'Domestic Longhair': 6,
#  'Chihuahua Shorthair/Cardigan Welsh Corgi': 6,
#  'Norwich Terrier Mix': 6,
#  'Mastiff Mix': 6,
#  'Labrador Retriever/Chow Chow': 6,
#  'Jack Russell Terrier': 6,
#  'Beagle': 6,
#  'Beagle/Chihuahua Shorthair': 6,
#  'Pembroke Welsh Corgi Mix': 6,
#  'Chihuahua Shorthair/Rat Terrier': 6,
#  'Basset Hound': 5,
#  'Labrador Retriever/Great Pyrenees': 5,
#  'German Shorthair Pointer Mix': 5,
#  'Himalayan Mix': 5,
#  'Weimaraner Mix': 5,
#  'Australian Shepherd': 5,
#  'Shiba Inu Mix': 5,
#  'Miniature Pinscher/Chihuahua Shorthair': 5,
#  'Great Pyrenees': 5,
#  'Boxer/Labrador Retriever': 5,
#  'Labrador Retriever/Australian Shepherd': 5,
#  'Border Collie': 5,
#  'Miniature Pinscher': 5,
#  'Miniature Poodle': 5,
#  'Papillon Mix': 5,
#  'Pit Bull/Boxer': 5,
#  'Persian Mix': 5,
#  'Wire Hair Fox Terrier Mix': 5,
#  'Australian Shepherd/Labrador Retriever': 5,
#  'Chihuahua Shorthair/Pug': 5,
#  'Harrier Mix': 5,
#  'Dachshund/Beagle': 5,
#  'Parson Russell Terrier Mix': 5,
#  'Labrador Retriever/Catahoula': 5,
#  'Chesa Bay Retr Mix': 5,
#  'Bichon Frise Mix': 5,
#  'Pit Bull/Chinese Sharpei': 5,
#  'Labrador Retriever/Plott Hound': 5,
#  'English Pointer Mix': 5,
#  'Golden Retriever': 5,
#  'Doberman Pinsch': 5,
#  'Great Dane Mix': 5,
#  'Chihuahua Shorthair/Cairn Terrier': 5,
#  'Ragdoll Mix': 5,
#  'Cairn Terrier/Chihuahua Shorthair': 5,
#  'Alaskan Husky Mix': 5,
#  'Belgian Malinois Mix': 5,
#  'Standard Poodle Mix': 5,
#  'Australian Cattle Dog/Border Collie': 5,
#  'Plott Hound/Labrador Retriever': 5,
#  'Dogo Argentino Mix': 5,
#  'Beauceron Mix': 5,
#  'Boston Terrier': 5,
#  'German Shepherd/Siberian Husky': 5,
#  'Havanese Mix': 5,
#  'Rottweiler/German Shepherd': 5,
#  'Dachshund Wirehair/Chihuahua Shorthair': 5,
#  'Labrador Retriever/Basset Hound': 5,
#  'Rat Terrier': 5,
#  'Anatol Shepherd': 5,
#  'Rottweiler/Labrador Retriever': 4,
#  'Dalmatian Mix': 4,
#  'Pug/Beagle': 4,
#  'American Staffordshire Terrier': 4,
#  'Basenji Mix': 4,
#  'Chihuahua Shorthair/Yorkshire Terrier': 4,
#  'Bulldog Mix': 4,
#  'Collie Rough Mix': 4,
#  'German Shepherd/Chow Chow': 4,
#  'Beagle/Dachshund': 4,
#  'Labrador Retriever/Blue Lacy': 4,
#  'Pomeranian': 4,
#  'Labrador Retriever/Anatol Shepherd': 4,
#  'Standard Schnauzer Mix': 4,
#  'Border Collie/Great Pyrenees': 4,
#  'Cardigan Welsh Corgi/Chihuahua Shorthair': 4,
#  'Siamese/Domestic Shorthair': 4,
#  'Schipperke Mix': 4,
#  'Catahoula/Labrador Retriever': 4,
#  'Labrador Retriever/Beagle': 4,
#  'Treeing Walker Coonhound Mix': 4,
#  'Pointer/Labrador Retriever': 4,
#  'Pit Bull/Australian Cattle Dog': 4,
#  'Chihuahua Longhair': 4,
#  'Italian Greyhound Mix': 4,
#  'Border Collie/German Shepherd': 4,
#  'Akita Mix': 4,
#  'West Highland Mix': 4,
#  'Miniature Poodle/Maltese': 4,
#  'Vizsla Mix': 4,
#  'St. Bernard Smooth Coat Mix': 4,
#  'Labrador Retriever/Rottweiler': 4,
#  'Chinese Sharpei': 4,
#  'Affenpinscher Mix': 4,
#  'German Shepherd/Australian Cattle Dog': 4,
#  'Chihuahua Shorthair/Beagle': 4,
#  'Pbgv Mix': 4,
#  'Mastiff/Chinese Sharpei': 4,
#  'Chihuahua Shorthair/Boston Terrier': 4,
#  'Yorkshire Terrier/Miniature Schnauzer': 4,
#  'Chihuahua Shorthair/Italian Greyhound': 4,
#  'Yorkshire Terrier/Miniature Poodle': 4,
#  'American Eskimo Mix': 4,
#  'Greyhound Mix': 4,
#  'Pharaoh Hound Mix': 4,
#  'Leonberger Mix': 4,
#  'English Bulldog': 4,
#  'Chihuahua Shorthair/Border Terrier': 4,
#  'Boston Terrier/Chihuahua Shorthair': 4,
#  'Jack Russell Terrier/Chihuahua Shorthair': 4,
#  'Lhasa Apso': 4,
#  'Dachshund/Manchester Terrier': 4,
#  'Japanese Bobtail Mix': 4,
#  'Bull Terrier': 4,
#  'Dachshund Longhair': 4,
#  'Border Collie/Australian Cattle Dog': 4,
#  'Catahoula/Pointer': 4,
#  'American Shorthair Mix': 4,
#  'Chow Chow/Pit Bull': 4,
#  'Dutch Shepherd Mix': 4,
#  'German Shepherd/Border Collie': 4,
#  'Rhod Ridgeback/Labrador Retriever': 4,
#  'Australian Kelpie': 4,
#  'Bichon Frise': 4,
#  'Great Pyrenees/Labrador Retriever': 4,
#  'Balinese Mix': 4,
#  'German Shepherd/Alaskan Malamute': 4,
#  'German Shepherd/Boxer': 4,
#  'Cavalier Span Mix': 4,
#  'Yorkshire Terrier/Chihuahua Shorthair': 4,
#  'Cocker Spaniel/Labrador Retriever': 4,
#  'Dachshund/Rat Terrier': 4,
#  'Catahoula': 4,
#  'Anatol Shepherd/Great Pyrenees': 4,
#  'Toy Fox Terrier Mix': 4,
#  'Australian Cattle Dog/Pit Bull': 4,
#  'Pit Bull/Chihuahua Shorthair': 4,
#  'Great Dane': 4,
#  'Australian Shepherd/Anatol Shepherd': 4,
#  'Bullmastiff Mix': 4,
#  'Jack Russell Terrier/Dachshund': 4,
#  'Angora Mix': 4,
#  'Staffordshire': 4,
#  'Greyhound': 3,
#  'Brittany Mix': 3,
#  'Labrador Retriever/Chinese Sharpei': 3,
#  'Toy Poodle': 3,
#  'Labrador Retriever/Rhod Ridgeback': 3,
#  'Pit Bull/Catahoula': 3,
#  'French Bulldog Mix': 3,
#  'Golden Retriever/Labrador Retriever': 3,
#  'Collie Smooth/Labrador Retriever': 3,
#  'Cairn Terrier': 3,
#  'Yorkshire Terrier/Cairn Terrier': 3,
#  'Smooth Fox Terrier Mix': 3,
#  'Beagle/German Shepherd': 3,
#  'Cardigan Welsh Corgi/Australian Cattle Dog': 3,
#  'Bloodhound Mix': 3,
#  'Carolina Dog/Chihuahua Shorthair': 3,
#  'German Shorthair Pointer': 3,
#  'Pit Bull/Basset Hound': 3,
#  'Airedale Terrier Mix': 3,
#  'Siberian Husky/Labrador Retriever': 3,
#  'Pbgv': 3,
#  'Beagle/Labrador Retriever': 3,
#  'Chow Chow/Australian Cattle Dog': 3,
#  'Chihuahua Shorthair/Miniature Pinscher': 3,
#  'German Shepherd/Chinese Sharpei': 3,
#  'Tonkinese Mix': 3,
#  'Labrador Retriever/Great Dane': 3,
#  'Boxer/Beagle': 3,
#  'Vizsla': 3,
#  'English Springer Spaniel Mix': 3,
#  'German Shepherd/Mastiff': 3,
#  'Anatol Shepherd/Labrador Retriever': 3,
#  'Australian Cattle Dog/German Shepherd': 3,
#  'Rhod Ridgeback': 3,
#  'Australian Cattle Dog/Pointer': 3,
#  'Bombay Mix': 3,
#  'Standard Poodle': 3,
#  'Blue Lacy/American Bulldog': 3,
#  'Miniature Poodle/Cocker Spaniel': 3,
#  'Patterdale Terr Mix': 3,
#  'Lhasa Apso/Miniature Poodle': 3,
#  'Anatol Shepherd/Border Collie': 3,
#  'German Shepherd/Rottweiler': 3,
#  'Manchester Terrier/Beagle': 3,
#  'American Pit Bull Terrier': 3,
#  'Landseer Mix': 3,
#  'American Bulldog/Pit Bull': 3,
#  'Bernese Mountain Dog Mix': 3,
#  'Chow Chow': 3,
#  'Beagle/Pug': 3,
#  'Chow Chow/Labrador Retriever': 3,
#  'Newfoundland Mix': 3,
#  'Pembroke Welsh Corgi': 3,
#  'Silky Terrier Mix': 3,
#  'German Shepherd/Collie Rough': 3,
#  'Labrador Retriever/Flat Coat Retriever': 3,
#  'English Coonhound Mix': 3,
#  'Welsh Terrier Mix': 3,
#  'Manchester Terrier/Dachshund': 3,
#  'Labrador Retriever/Siberian Husky': 3,
#  'Great Pyrenees/Border Collie': 3,
#  'Chihuahua Shorthair/Pomeranian': 3,
#  'Feist Mix': 3,
#  'Weimaraner': 3,
#  'Australian Shepherd/Australian Cattle Dog': 3,
#  'American Bulldog': 3,
#  'Wire Hair Fox Terrier/Chihuahua Shorthair': 3,
#  'Pit Bull/Plott Hound': 3,
#  'Catahoula/Australian Cattle Dog': 3,
#  'Lhasa Apso/Shih Tzu': 3,
#  'Dachshund/Labrador Retriever': 3,
#  'Cairn Terrier/Yorkshire Terrier': 3,
#  'Parson Russell Terrier': 3,
#  'Yorkshire Terrier/Maltese': 3,
#  'Australian Cattle Dog/Catahoula': 3,
#  'Great Dane/Labrador Retriever': 3,
#  'Rat Terrier/Beagle': 3,
#  'Australian Cattle Dog/Boxer': 3,
#  'Dogue De Bordeaux Mix': 3,
#  'Border Collie/Australian Shepherd': 3,
#  'Jack Russell Terrier/Beagle': 3,
#  'Chihuahua Shorthair/Miniature Schnauzer': 3,
#  'Maine Coon': 3,
#  'Siberian Husky/German Shepherd': 3,
#  'Australian Cattle Dog/Beagle': 3,
#  'Chinese Crested Mix': 3,
#  'Black Mouth Cur/German Shepherd': 3,
#  'Shih Tzu/Havanese': 3,
#  'Australian Cattle Dog/Chow Chow': 3,
#  'Swedish Vallhund Mix': 3,
#  'Canaan Dog Mix': 3,
#  'Anatol Shepherd/Redbone Hound': 3,
#  'Pit Bull/Pointer': 3,
#  'Standard Poodle/Labrador Retriever': 3,
#  'Dachshund/Australian Cattle Dog': 3,
#  'Treeing Cur Mix': 3,
#  'Irish Wolfhound Mix': 3,
#  'Australian Shepherd/Chow Chow': 3,
#  'Rat Terrier/Cardigan Welsh Corgi': 3,
#  'Schnauzer Giant Mix': 3,
#  'West Highland': 3,
#  'Black Mouth Cur': 3,
#  'Australian Shepherd/Border Collie': 3,
#  'Pointer/Catahoula': 3,
#  'Labrador Retriever/Queensland Heeler': 3,
#  'Finnish Spitz Mix': 3,
#  'Boxer/Black Mouth Cur': 3,
#  'Labrador Retriever/Black/Tan Hound': 3,
#  'Jack Russell Terrier/Australian Cattle Dog': 3,
#  'Yorkshire Terrier/Chihuahua Longhair': 3,
#  'Black Mouth Cur/Australian Cattle Dog': 3,
#  'Alaskan Malamute Mix': 3,
#  'Boxer/Australian Cattle Dog': 3,
#  'Tibetan Spaniel Mix': 3,
#  'Basset Hound/Labrador Retriever': 3,
#  'Weimaraner/Labrador Retriever': 3,
#  'Australian Cattle Dog/Staffordshire': 3,
#  'Beagle/Boxer': 3,
#  'Pit Bull/Mastiff': 3,
#  'Jack Russell Terrier/Pit Bull': 3,
#  'German Shepherd/Cardigan Welsh Corgi': 3,
#  'Jindo Mix': 3,
#  'Standard Schnauzer': 3,
#  'Pit Bull/German Shepherd': 3,
#  'German Shepherd/Pit Bull': 3,
#  'Pekingese': 3,
#  'Dachshund Wirehair/Border Terrier': 3,
#  'Irish Terrier Mix': 3,
#  'Beagle/Basset Hound': 3,
#  'Black Mouth Cur/Catahoula': 3,
#  'Boxer/American Staffordshire Terrier': 3,
#  'Miniature Poodle/Dachshund': 3,
#  'American Bulldog/Labrador Retriever': 3,
#  'Chow Chow/German Shepherd': 3,
#  'Chihuahua Shorthair/Manchester Terrier': 3,
#  'Tibetan Terrier Mix': 3,
#  'Miniature Poodle/Yorkshire Terrier': 3,
#  'Border Terrier/Yorkshire Terrier': 3,
#  'Rat Terrier/Australian Cattle Dog': 3,
#  'Boykin Span Mix': 3,
#  'Alaskan Husky/Australian Shepherd': 3,
#  'Collie Rough/Australian Shepherd': 3,
#  'Belgian Malinois': 3,
#  'St. Bernard Rough Coat Mix': 2,
#  'Labrador Retriever/Staffordshire': 2,
#  'Abyssinian Mix': 2,
#  'American Eskimo': 2,
#  'Boxer/Rhod Ridgeback': 2,
#  'Irish Setter/Pit Bull': 2,
#  'Glen Of Imaal Mix': 2,
#  'Border Terrier/Chihuahua Shorthair': 2,
#  'Cavalier Span': 2,
#  'Jack Russell Terrier/Labrador Retriever': 2,
#  'American Foxhound Mix': 2,
#  'German Shepherd/Anatol Shepherd': 2,
#  'Cairn Terrier/Dachshund': 2,
#  'Labrador Retriever/Redbone Hound': 2,
#  'Chihuahua Longhair/Cairn Terrier': 2,
#  'Dogo Argentino': 2,
#  'Lhasa Apso/Miniature Schnauzer': 2,
#  'Border Collie/Chow Chow': 2,
#  'Himalayan': 2,
#  'Whippet/Dachshund': 2,
#  'Shih Tzu/Miniature Poodle': 2,
#  'Plott Hound': 2,
#  'Bluetick Hound Mix': 2,
#  'Cocker Spaniel/Chihuahua Shorthair': 2,
#  'Old English Sheepdog': 2,
#  'Pointer/Boxer': 2,
#  'Labrador Retriever/Pembroke Welsh Corgi': 2,
#  'Miniature Schnauzer/Chihuahua Shorthair': 2,
#  'Chow Chow/Chinese Sharpei': 2,
#  'Australian Cattle Dog/Anatol Shepherd': 2,
#  'Border Collie/Boxer': 2,
#  'Basset Hound/Australian Cattle Dog': 2,
#  'Siamese/Japanese Bobtail': 2,
#  'Skye Terrier Mix': 2,
#  'Cane Corso Mix': 2,
#  'Australian Cattle Dog/Bloodhound': 2,
#  'Maltese/Toy Poodle': 2,
#  'Bengal': 2,
#  'Beagle/Standard Poodle': 2,
#  'Bedlington Terr Mix': 2,
#  'Australian Cattle Dog/Alaskan Husky': 2,
#  'West Highland/Cairn Terrier': 2,
#  'Boxer/Miniature Poodle': 2,
#  'Chinese Sharpei/Labrador Retriever': 2,
#  'Labrador Retriever/Dalmatian': 2,
#  'British Shorthair Mix': 2,
#  'Catahoula/Alaskan Husky': 2,
#  'Old English Bulldog Mix': 2,
#  'Shiba Inu': 2,
#  'Pit Bull/Rottweiler': 2,
#  'Shetland Sheepdog': 2,
#  'American Staffordshire Terrier/Labrador Retriever': 2,
#  'Cocker Spaniel/Miniature Poodle': 2,
#  'Rhod Ridgeback/Pit Bull': 2,
#  'Pomeranian/Chihuahua Shorthair': 2,
#  'Australian Cattle Dog/Akita': 2,
#  'Anatol Shepherd/Catahoula': 2,
#  'Border Collie/Pit Bull': 2,
#  'Yorkshire Terrier/Rat Terrier': 2,
#  'Chihuahua Shorthair/Toy Fox Terrier': 2,
#  'Jack Russell Terrier/Shih Tzu': 2,
#  'Labrador Retriever/Greyhound': 2,
#  'Flat Coat Retriever/Papillon': 2,
#  'Miniature Poodle/Chihuahua Shorthair': 2,
#  'Ibizan Hound Mix': 2,
#  'Newfoundland/Labrador Retriever': 2,
#  'Bull Terrier Miniature Mix': 2,
#  'American Pit Bull Terrier/Boxer': 2,
#  'Pointer/Pit Bull': 2,
#  'Chihuahua Shorthair/Wire Hair Fox Terrier': 2,
#  'Neapolitan Mastiff Mix': 2,
#  'Black/Tan Hound': 2,
#  'Border Collie/Catahoula': 2,
#  'Labrador Retriever/Cocker Spaniel': 2,
#  'Chihuahua Shorthair/Chinese Sharpei': 2,
#  'Labrador Retriever/Jack Russell Terrier': 2,
#  'Pit Bull/Boston Terrier': 2,
#  'Shih Tzu/Miniature Schnauzer': 2,
#  'Presa Canario Mix': 2,
#  'Pointer/Australian Cattle Dog': 2,
#  'Dachshund Wirehair/Chihuahua Longhair': 2,
#  'Shetland Sheepdog/Chihuahua Longhair': 2,
#  'Domestic Longhair/Persian': 2,
#  'Rat Terrier/Boston Terrier': 2,
#  'Golden Retriever/Standard Poodle': 2,
#  'German Wirehaired Pointer': 2,
#  'Catahoula/Chinese Sharpei': 2,
#  'Snowshoe': 2,
#  'Dachshund Longhair/Cardigan Welsh Corgi': 2,
#  'Manchester Terrier/Australian Kelpie': 2,
#  'Border Collie/Akita': 2,
#  'Siberian Husky/Australian Cattle Dog': 2,
#  'Australian Shepherd/Chihuahua Shorthair': 2,
#  'Black Mouth Cur/Labrador Retriever': 2,
#  'Pomeranian/Chihuahua Longhair': 2,
#  'Greater Swiss Mountain Dog Mix': 2,
#  'Great Pyrenees/Catahoula': 2,
#  'Domestic Medium Hair/Siamese': 2,
#  'Keeshond Mix': 2,
#  'Cardigan Welsh Corgi/Cocker Spaniel': 2,
#  'Catahoula/Cardigan Welsh Corgi': 2,
#  'Podengo Pequeno Mix': 2,
#  'Unknown Mix': 2,
#  'German Shepherd/Collie Smooth': 2,
#  'French Bulldog/Chihuahua Shorthair': 2,
#  'Labrador Retriever/Australian Kelpie': 2,
#  'Dalmatian': 2,
#  'Bruss Griffon/Chihuahua Shorthair': 2,
#  'Boxer/Catahoula': 2,
#  'Pit Bull/English Bulldog': 2,
#  'Chihuahua Shorthair/Pit Bull': 2,
#  'Australian Kelpie/Australian Shepherd': 2,
#  'Miniature Schnauzer/Yorkshire Terrier': 2,
#  'Pointer/American Pit Bull Terrier': 2,
#  'Dachshund Wirehair/Toy Poodle': 2,
#  'Chihuahua Shorthair/German Shepherd': 2,
#  'American Bulldog/Pointer': 2,
#  'Manchester Terrier/Chihuahua Shorthair': 2,
#  'Brittany': 2,
#  'Whippet/Labrador Retriever': 2,
#  'Pointer': 2,
#  'German Shepherd/Doberman Pinsch': 2,
#  'Brittany/Labrador Retriever': 2,
#  'Pointer/Harrier': 2,
#  'Australian Terrier Mix': 2,
#  'Labrador Retriever/Collie Smooth': 2,
#  'Dachshund/Whippet': 2,
#  'Chihuahua Shorthair/Australian Cattle Dog': 2,
#  'German Wirehaired Pointer Mix': 2,
#  'Labrador Retriever/Standard Poodle': 2,
#  'Rottweiler/Chow Chow': 2,
#  'Plott Hound/Pit Bull': 2,
#  'English Foxhound': 2,
#  'Chow Chow/Basset Hound': 2,
#  'Jack Russell Terrier/Pug': 2,
#  'Australian Shepherd/Cocker Spaniel': 2,
#  'Miniature Schnauzer/Cairn Terrier': 2,
#  'Mastiff/Rottweiler': 2,
#  'Harrier': 2,
#  'Chihuahua Longhair/Maltese': 2,
#  'Black Mouth Cur/Dachshund': 2,
#  'Miniature Poodle/Labrador Retriever': 2,
#  'Wirehaired Pointing Griffon Mix': 2,
#  'Norfolk Terrier/Yorkshire Terrier': 2,
#  'Chihuahua Shorthair/Dachshund Wirehair': 2,
#  'Labrador Retriever/Golden Retriever': 2,
#  'Saluki Mix': 2,
#  'Akita': 2,
#  'Pixiebob Shorthair Mix': 2,
#  'Carolina Dog/Labrador Retriever': 2,
#  'German Shepherd/Catahoula': 2,
#  'Basenji/Chihuahua Longhair': 2,
#  'Pointer/Bull Terrier': 2,
#  'Picardy Sheepdog Mix': 2,
#  'Australian Shepherd/Siberian Husky': 2,
#  'Cornish Rex Mix': 2,
#  'Field Spaniel Mix': 2,
#  'Golden Retriever/Pembroke Welsh Corgi': 2,
#  'Shetland Sheepdog/Basenji': 2,
#  'American Pit Bull Terrier/Labrador Retriever': 2,
#  'Collie Rough/Chinese Sharpei': 2,
#  'Papillon/Australian Cattle Dog': 2,
#  'Great Pyrenees/Collie Rough': 2,
#  'Chihuahua Longhair/Pekingese': 2,
#  'Labrador Retriever/Weimaraner': 2,
#  'Jack Russell Terrier/Italian Greyhound': 2,
#  'Border Collie/Great Dane': 2,
#  'Patterdale Terr/Chihuahua Shorthair': 2,
#  'Basset Hound/English Pointer': 2,
#  'German Shepherd/Akita': 2,
#  'Australian Cattle Dog/Bull Terrier': 2,
#  'Maltese/Papillon': 2,
#  'Maltese/Shih Tzu': 2,
#  'Labrador Retriever/Spanish Water Dog': 2,
#  'Akita/Chow Chow': 2,
#  'Pointer/Border Collie': 2,
#  'English Bulldog/Beagle': 2,
#  'Anatol Shepherd/Siberian Husky': 2,
#  'Australian Cattle Dog/Rat Terrier': 2,
#  'Norfolk Terrier/Dachshund': 2,
#  'Labrador Retriever/American Pit Bull Terrier': 2,
#  'Whippet/Miniature Pinscher': 2,
#  'Chihuahua Longhair/West Highland': 2,
#  'Shetland Sheepdog/Dachshund Longhair': 2,
#  'Boxer/English Bulldog': 2,
#  'English Bulldog/Boxer': 2,
#  'Miniature Poodle/English Cocker Spaniel': 2,
#  'Labrador Retriever/Black Mouth Cur': 2,
#  'Cardigan Welsh Corgi/Cardigan Welsh Corgi': 2,
#  'Catahoula/Pit Bull': 2,
#  'Boxer/Harrier': 2,
#  'Boxer/Chow Chow': 2,
#  'Labrador Retriever/Collie Rough': 2,
#  'Border Collie/Anatol Shepherd': 2,
#  'Vizsla/Catahoula': 2,
#  'Weimaraner/Pit Bull': 2,
#  'Akita/Australian Cattle Dog': 2,
#  'Blue Lacy/Labrador Retriever': 2,
#  'Norfolk Terrier/Cairn Terrier': 2,
#  'Great Pyrenees/Australian Shepherd': 2,
#  'Chihuahua Longhair/Italian Greyhound': 2,
#  'Ibizan Hound/Pit Bull': 2,
#  'Bull Terrier/Jack Russell Terrier': 2,
#  'Alaskan Husky/Border Collie': 2,
#  'Boston Terrier/Dachshund': 2,
#  'Chihuahua Shorthair/Pekingese': 2,
#  'Miniature Pinscher/Maltese': 2,
#  'Jack Russell Terrier/Miniature Schnauzer': 2,
#  'Maltese/Yorkshire Terrier': 2,
#  'Great Pyrenees/Standard Poodle': 2,
#  'Dachshund Longhair/Miniature Schnauzer': 2,
#  'Queensland Heeler/Basset Hound': 2,
#  'English Shepherd Mix': 2,
#  'Rottweiler/Pit Bull': 2,
#  'St. Bernard Rough Coat': 2,
#  'Cairn Terrier/Scottish Terrier': 2,
#  'Boxer/Bulldog': 2,
#  'Great Pyrenees/German Shepherd': 2,
#  'Ragdoll': 2,
#  'Siberian Husky/Pit Bull': 2,
#  'Shih Tzu/Cocker Spaniel': 2,
#  'Pekingese/Lhasa Apso': 2,
#  'Pit Bull/Pit Bull': 2,
#  'Dachshund Wirehair/Miniature Poodle': 2,
#  'Jack Russell Terrier/Whippet': 2,
#  'Black Mouth Cur/Blue Lacy': 2,
#  'British Shorthair': 2,
#  'Australian Cattle Dog/Queensland Heeler': 2,
#  'Pharaoh Hound': 2,
#  'Miniature Schnauzer/Jack Russell Terrier': 2,
#  'German Shepherd/Greyhound': 2,
#  'Shih Tzu/Cavalier Span': 2,
#  'Domestic Longhair/Rex': 2,
#  'German Shepherd/Nova Scotia Duck Tolling Retriever': 2,
#  'Lhasa Apso/Pbgv': 2,
#  'Domestic Longhair/Russian Blue': 2,
#  'Bernese Mountain Dog/Rottweiler': 2,
#  'Harrier/Catahoula': 2,
#  'Labrador Retriever/Miniature Poodle': 2,
#  'Greyhound/Great Dane': 2,
#  'English Coonhound/Border Collie': 2,
#  'Cavalier Span/Papillon': 2,
#  'Belgian Sheepdog Mix': 2,
#  'Border Terrier/Pug': 2,
#  'Collie Rough/Pointer': 2,
#  'Chinese Sharpei/Airedale Terrier': 2,
#  'Doberman Pinsch/Pit Bull': 2,
#  'Akita/Siberian Husky': 2,
#  'Dachshund/Havanese': 2,
#  'Pit Bull/Bulldog': 2,
#  'Standard Schnauzer/Border Terrier': 2,
#  'Pharaoh Hound/Border Collie': 2,
#  'Rat Terrier/Jack Russell Terrier': 2,
#  'Manchester Terrier/Jack Russell Terrier': 2,
#  'Chihuahua Shorthair/Pembroke Welsh Corgi': 2,
#  'Chihuahua Shorthair/Basset Hound': 2,
#  'Australian Cattle Dog/Pembroke Welsh Corgi': 2,
#  'Pointer/Queensland Heeler': 2,
#  'Ocicat Mix': 2,
#  'Norfolk Terrier/Dachshund Wirehair': 2,
#  'Beagle/Pembroke Welsh Corgi': 2,
#  'Border Terrier/Cardigan Welsh Corgi': 2,
#  'Bulldog': 2,
#  'Lhasa Apso/Yorkshire Terrier': 2,
#  'Jack Russell Terrier/Welsh Terrier': 2,
#  'Border Collie/Plott Hound': 2,
#  'American Pit Bull Terrier/American Pit Bull Terrier': 2,
#  'Cardigan Welsh Corgi/Rat Terrier': 2,
#  'Golden Retriever/Great Pyrenees': 2,
#  'American Pit Bull Terrier/Pointer': 2,
#  'Boxer/Mastiff': 2,
#  'Anatol Shepherd/German Shepherd': 2,
#  'Alaskan Malamute/Border Collie': 2,
#  'Cardigan Welsh Corgi/Chihuahua Longhair': 2,
#  'Australian Shepherd/Boxer': 2,
#  'Miniature Poodle/Australian Cattle Dog': 2,
#  'Dachshund/Parson Russell Terrier': 2,
#  'Pit Bull/Dalmatian': 2,
#  'Golden Retriever/German Shepherd': 2,
#  'Chihuahua Shorthair/Affenpinscher': 2,
#  'Finnish Spitz': 2,
#  'Shih Tzu/Cardigan Welsh Corgi': 2,
#  'Beagle/Rat Terrier': 2,
#  'Dachshund/Jack Russell Terrier': 2,
#  'Welsh Springer Spaniel Mix': 2,
#  'Queensland Heeler/Great Dane': 2,
#  'Treeing Tennesse Brindle': 2,
#  'Brittany/Chihuahua Shorthair': 2,
#  'Harrier/Pointer': 2,
#  'Miniature Schnauzer/Soft Coated Wheaten Terrier': 2,
#  'Shih Tzu/Dachshund': 2,
#  'Dachshund/Pembroke Welsh Corgi': 2,
#  'Doberman Pinsch/Border Collie': 2,
#  'Scottish Terrier/Miniature Poodle': 2,
#  'German Shepherd/Black/Tan Hound': 2,
#  'Rat Terrier/Basenji': 2,
#  'Australian Kelpie/American Pit Bull Terrier': 2,
#  'Jack Russell Terrier/Basset Hound': 2,
#  'Labrador Retriever/Mastiff': 2,
#  'Carolina Dog/Pit Bull': 2,
#  'Redbone Hound/Labrador Retriever': 2,
#  'Belgian Malinois/Australian Shepherd': 2,
#  'Labrador Retriever/English Pointer': 2,
#  'Beagle/Pointer': 2,
#  'Silky Terrier/Yorkshire Terrier': 2,
#  'Pekingese/Chihuahua Shorthair': 2,
#  'Cardigan Welsh Corgi/Miniature Pinscher': 2,
#  'Labrador Retriever/Doberman Pinsch': 2,
#  'Black Mouth Cur/Boxer': 2,
#  'Queensland Heeler/Dachshund': 2,
#  'Chow Chow/Golden Retriever': 2,
#  'Dutch Shepherd/Anatol Shepherd': 2,
#  'St. Bernard Rough Coat/Standard Schnauzer': 2,
#  'Jack Russell Terrier/Miniature Poodle': 2,
#  'Basenji/Jack Russell Terrier': 2,
#  'Miniature Schnauzer/West Highland': 2,
#  'Welsh Springer Spaniel': 2,
#  'Border Collie/Greyhound': 2,
#  'Border Terrier/West Highland': 2,
#  'Dachshund/Australian Kelpie': 2,
#  'Collie Rough/German Shepherd': 2,
#  'Shih Tzu/Australian Shepherd': 2,
#  'Soft Coated Wheaten Terrier/Standard Poodle': 2,
#  'Collie Smooth/Chow Chow': 2,
#  'Parson Russell Terrier/Chihuahua Shorthair': 2,
#  'Domestic Shorthair/Siamese': 2,
#  'Cardigan Welsh Corgi/German Shepherd': 2,
#  'Newfoundland/Queensland Heeler': 2,
#  'German Shepherd/Swedish Vallhund': 2,
#  'English Bulldog/Pit Bull': 2,
#  'Wire Hair Fox Terrier/German Shepherd': 2,
#  'Dachshund Wirehair/Cairn Terrier': 2,
#  'Standard Schnauzer/Toy Poodle': 2,
#  'Queensland Heeler/Chihuahua Shorthair': 2,
#  'Dachshund Longhair/Australian Shepherd': 2,
#  'Pembroke Welsh Corgi/Dachshund': 2,
#  'Norfolk Terrier/Chihuahua Shorthair': 2,
#  'Shiba Inu/Siberian Husky': 2,
#  'Golden Retriever/Dachshund': 2,
#  'Collie Rough/Australian Cattle Dog': 2,
#  'Beagle/Treeing Walker Coonhound': 2,
#  'Plott Hound/Boxer': 2,
#  'English Coonhound/Italian Greyhound': 2,
#  'Pointer/Brittany': 2,
#  'Papillon': 2,
#  'Plott Hound/Carolina Dog': 2,
#  'Boxer/Jack Russell Terrier': 2,
#  'Catahoula/American Bulldog': 2,
#  'Catahoula/Anatol Shepherd': 2,
#  'English Springer Spaniel': 2,
#  'Border Terrier/Chihuahua Longhair': 1,
#  'Collie Rough/Labrador Retriever': 1,
#  'Maltese/Chihuahua Shorthair': 1,
#  'Carolina Dog': 1,
#  'Dachshund Longhair/Chihuahua Longhair': 1,
#  'Boxer/Staffordshire': 1,
#  'Shetland Sheepdog/Brittany': 1,
#  'Schipperke/Chihuahua Shorthair': 1,
#  'Australian Shepherd/Nova Scotia Duck Tolling Retriever': 1,
#  'Golden Retriever/Akita': 1,
#  'Great Pyrenees/Pit Bull': 1,
#  'Turkish Van Mix': 1,
#  'Boxer/American Pit Bull Terrier': 1,
#  'Catahoula/Plott Hound': 1,
#  'Dachshund/Miniature Poodle': 1,
#  'Border Collie/Standard Schnauzer': 1,
#  'St. Bernard Rough Coat/German Shepherd': 1,
#  'Boxer/Boston Terrier': 1,
#  'Australian Cattle Dog/Australian Shepherd': 1,
#  'Whippet/Beagle': 1,
#  'Pekingese/Cavalier Span': 1,
#  'Yorkshire Terrier/Dachshund Wirehair': 1,
#  'Dachshund Wirehair/Norfolk Terrier': 1,
#  'Chihuahua Longhair/Cardigan Welsh Corgi': 1,
#  'Cardigan Welsh Corgi': 1,
#  'Pembroke Welsh Corgi/Pit Bull': 1,
#  'Sphynx': 1,
#  'Yorkshire Terrier/Pomeranian': 1,
#  'Pit Bull/American Foxhound': 1,
#  'Cardigan Welsh Corgi/Jack Russell Terrier': 1,
#  'Jack Russell Terrier/Rat Terrier': 1,
#  'Alaskan Malamute/Australian Kelpie': 1,
#  'Finnish Spitz/Dachshund': 1,
#  'Australian Cattle Dog/Dachshund': 1,
#  'Border Collie/Basenji': 1,
#  'Spanish Mastiff Mix': 1,
#  'Bluetick Hound': 1,
#  'Border Collie/Mastiff': 1,
#  'Basenji/Australian Cattle Dog': 1,
#  'Nova Scotia Duck Tolling Retriever Mix': 1,
#  'Australian Cattle Dog/Collie Smooth': 1,
#  'Staffordshire/French Bulldog': 1,
#  'Pit Bull/Bull Terrier': 1,
#  'Collie Rough': 1,
#  'Cocker Spaniel/Toy Poodle': 1,
#  'St. Bernard Rough Coat/Border Collie': 1,
#  'Dachshund Wirehair': 1,
#  'Jack Russell Terrier/Papillon': 1,
#  'Presa Canario': 1,
#  'German Shepherd/Alaskan Husky': 1,
#  'Staffordshire/Labrador Retriever': 1,
#  'Golden Retriever/Finnish Spitz': 1,
#  'Cocker Spaniel/Golden Retriever': 1,
#  'Labrador Retriever/Newfoundland': 1,
#  'Border Collie/Dachshund': 1,
#  'Chihuahua Shorthair/Parson Russell Terrier': 1,
#  'Flat Coat Retriever/Australian Cattle Dog': 1,
#  'Australian Cattle Dog/Collie Rough': 1,
#  'Devon Rex Mix': 1,
#  'Bruss Griffon/Dachshund': 1,
#  'Boerboel Mix': 1,
#  'Cairn Terrier/Miniature Schnauzer': 1,
#  'Cane Corso/Mastiff': 1,
#  'Rat Terrier/Pit Bull': 1,
#  'Great Pyrenees/Pointer': 1,
#  'Scottish Terrier/Cairn Terrier': 1,
#  'Staffordshire/Bull Terrier': 1,
#  'Labrador Retriever/American Bulldog': 1,
#  'Australian Cattle Dog/Dalmatian': 1,
#  'Basset Hound/Beauceron': 1,
#  'Beagle/Jack Russell Terrier': 1,
#  'Great Pyrenees/Rottweiler': 1,
#  'Border Collie/Shetland Sheepdog': 1,
#  'Border Collie/Parson Russell Terrier': 1,
#  'Pit Bull/Flat Coat Retriever': 1,
#  'Great Pyrenees/Anatol Shepherd': 1,
#  'Border Terrier/Affenpinscher': 1,
#  'Otterhound Mix': 1,
#  'Miniature Schnauzer/Whippet': 1,
#  'American Bulldog/Great Pyrenees': 1,
#  'Pomeranian/Schipperke': 1,
#  'Manx': 1,
#  'Norfolk Terrier/Border Terrier': 1,
#  'Japanese Chin': 1,
#  'Rottweiler/Basset Hound': 1,
#  'Jack Russell Terrier/American Staffordshire Terrier': 1,
#  'Australian Shepherd/Beagle': 1,
#  'Boston Terrier/Pug': 1,
#  'German Pinscher Mix': 1,
#  'Boxer/American Bulldog': 1,
#  'Cardigan Welsh Corgi/Australian Kelpie': 1,
#  'Soft Coated Wheaten Terrier/Labrador Retriever': 1,
#  'American Bulldog/Mastiff': 1,
#  'Queensland Heeler/Shetland Sheepdog': 1,
#  'Beagle/Cavalier Span': 1,
#  'American Staffordshire Terrier/French Bulldog': 1,
#  'Pit Bull/Rhod Ridgeback': 1,
#  'Australian Shepherd/Rottweiler': 1,
#  'Rat Terrier/Queensland Heeler': 1,
#  'Chow Chow/English Cocker Spaniel': 1,
#  'Toy Fox Terrier/Dachshund': 1,
#  'Pit Bull/Beagle': 1,
#  'Pit Bull/Pug': 1,
#  'Burmese': 1,
#  'Staffordshire/Beagle': 1,
#  'Whippet/Shetland Sheepdog': 1,
#  'Swedish Vallhund/Miniature Poodle': 1,
#  'Jack Russell Terrier/Cardigan Welsh Corgi': 1,
#  'Pit Bull/Chow Chow': 1,
#  'Catahoula/Border Collie': 1,
#  'Great Dane/Staffordshire': 1,
#  'Australian Kelpie/Alaskan Husky': 1,
#  'Plott Hound/Black/Tan Hound': 1,
#  'Airedale Terrier/Miniature Schnauzer': 1,
#  'Pit Bull/Border Collie': 1,
#  'Basenji/Chihuahua Shorthair': 1,
#  'French Bulldog/English Bulldog': 1,
#  'Havana Brown Mix': 1,
#  'Shetland Sheepdog/Cavalier Span': 1,
#  'Irish Terrier/Labrador Retriever': 1,
#  'Mastiff/Pit Bull': 1,
#  'English Foxhound Mix': 1,
#  'Boston Terrier/Labrador Retriever': 1,
#  'Staffordshire/Boston Terrier': 1,
#  'Pit Bull/American Bulldog': 1,
#  'German Pinscher/Whippet': 1,
#  'Dachshund/German Shepherd': 1,
#  'Lowchen Mix': 1,
#  'Miniature Pinscher/Australian Cattle Dog': 1,
#  'Cairn Terrier/Chihuahua Longhair': 1,
#  'Dachshund/Chinese Sharpei': 1,
#  'Newfoundland/Great Pyrenees': 1,
#  'Papillon/Pomeranian': 1,
#  'Doberman Pinsch/Labrador Retriever': 1,
#  'Pit Bull/Siberian Husky': 1,
#  'German Shepherd/Bull Terrier': 1,
#  'Chihuahua Shorthair/Whippet': 1,
#  'Pug/Staffordshire': 1,
#  'Basset Hound/English Cocker Spaniel': 1,
#  'Pug/Italian Greyhound': 1,
#  'Bruss Griffon': 1,
#  'Havanese': 1,
#  'Blue Lacy/Pit Bull': 1,
#  'Wire Hair Fox Terrier': 1,
#  'Black Mouth Cur/Basset Hound': 1,
#  'Beagle/Cocker Spaniel': 1,
#  'Boston Terrier/Miniature Schnauzer': 1,
#  'American Eskimo/Australian Shepherd': 1,
#  'Collie Smooth': 1,
#  'Boxer/Redbone Hound': 1,
#  'Australian Cattle Dog/Chinese Sharpei': 1,
#  'Dachshund/Harrier': 1,
#  'Pug/Pomeranian': 1,
#  'Chihuahua Shorthair/Cocker Spaniel': 1,
#  'Dachshund/Pit Bull': 1,
#  'Miniature Pinscher/Pomeranian': 1,
#  'Labrador Retriever/St. Bernard Rough Coat': 1,
#  'Chinese Sharpei/Great Dane': 1,
#  'Blue Lacy': 1,
#  'Beagle/Queensland Heeler': 1,
#  'Border Collie/Pointer': 1,
#  'Black/Tan Hound/German Shepherd': 1,
#  'Manx/Domestic Shorthair': 1,
#  'Pekingese/Pug': 1,
#  'Cocker Spaniel/Standard Poodle': 1,
#  'American Staffordshire Terrier/Plott Hound': 1,
#  'Rottweiler/Beagle': 1,
#  'Collie Smooth/German Shepherd': 1,
#  'Leonberger': 1,
#  'Dachshund Longhair/Cairn Terrier': 1,
#  'Queensland Heeler': 1,
#  'Redbone Hound': 1,
#  'Chow Chow/Siberian Husky': 1,
#  'American Foxhound/Pointer': 1,
#  'Jack Russell Terrier/Dachshund Wirehair': 1,
#  'Australian Kelpie/Blue Lacy': 1,
#  'Pembroke Welsh Corgi/Chihuahua Shorthair': 1,
#  'Alaskan Malamute/Akita': 1,
#  'Australian Kelpie/Pit Bull': 1,
#  'Staffordshire/Blue Lacy': 1,
#  'Basenji/Chow Chow': 1,
#  'Shih Tzu/Maltese': 1,
#  'Pembroke Welsh Corgi/Basset Hound': 1,
#  'Bull Terrier/Pit Bull': 1,
#  'Border Terrier/Miniature Poodle': 1,
#  'Jack Russell Terrier/Cairn Terrier': 1,
#  'Jack Russell Terrier/Basenji': 1,
#  'Skye Terrier/Miniature Poodle': 1,
#  'Catahoula/Australian Shepherd': 1,
#  'Border Terrier': 1,
#  'Dachshund/Miniature Pinscher': 1,
#  'Pomeranian/Jack Russell Terrier': 1,
#  'Catahoula/Black Mouth Cur': 1,
#  'St. Bernard Rough Coat/Labrador Retriever': 1,
#  'Black/Tan Hound/Black Mouth Cur': 1,
#  'Pit Bull/Blue Lacy': 1,
#  'Pembroke Welsh Corgi/Brittany': 1,
#  'Whippet/Whippet': 1,
#  'Boxer/Great Dane': 1,
#  'Dachshund/Bull Terrier': 1,
#  'Golden Retriever/Border Collie': 1,
#  'Border Terrier/Bruss Griffon': 1,
#  'Cardigan Welsh Corgi/Cairn Terrier': 1,
#  'Doberman Pinsch/Vizsla': 1,
#  'St. Bernard Smooth Coat': 1,
#  'Staffordshire/Boxer': 1,
#  'Greyhound/Dalmatian': 1,
#  'English Pointer': 1,
#  'English Cocker Spaniel Mix': 1,
#  'Dachshund Wirehair/Rat Terrier': 1,
#  'Chihuahua Shorthair/Welsh Terrier': 1,
#  'Boxer/Pointer': 1,
#  'Norwich Terrier/Pug': 1,
#  'Finnish Spitz/Chow Chow': 1,
#  'Nova Scotia Duck Tolling Retriever': 1,
#  'Shih Tzu/Pekingese': 1,
#  'Dachshund Longhair/Chihuahua Shorthair': 1,
#  'Dachshund Longhair/Pembroke Welsh Corgi': 1,
#  'Australian Cattle Dog/Golden Retriever': 1,
#  'Pekingese/Dachshund': 1,
#  'Anatol Shepherd/Collie Rough': 1,
#  'Airedale Terrier': 1,
#  'Dachshund/Pug': 1,
#  'Soft Coated Wheaten Terrier': 1,
#  'Maltese/Cocker Spaniel': 1,
#  'Catahoula/Boxer': 1,
#  'Labrador Retriever/Border Terrier': 1,
#  'Beagle/Staffordshire': 1,
#  'Cairn Terrier/Border Collie': 1,
#  'Labrador Retriever/Boston Terrier': 1,
#  'Dachshund/German Pinscher': 1,
#  'Border Collie/Doberman Pinsch': 1,
#  'Golden Retriever/Chow Chow': 1,
#  'German Shepherd/Australian Shepherd': 1,
#  'Labrador Retriever/Alaskan Husky': 1,
#  'Dachshund/English Foxhound': 1,
#  'Golden Retriever/Australian Cattle Dog': 1,
#  'American Eskimo/Border Collie': 1,
#  'Beagle/Chinese Sharpei': 1,
#  'German Shepherd/Pembroke Welsh Corgi': 1,
#  'Siberian Husky/Border Collie': 1,
#  'German Shepherd/Black Mouth Cur': 1,
#  'Blue Lacy/Australian Kelpie': 1,
#  'Persian': 1,
#  'Pointer/Collie Smooth': 1,
#  'Domestic Shorthair/Domestic Medium Hair': 1,
#  'Beagle/American Staffordshire Terrier': 1,
#  'Chow Chow/Australian Kelpie': 1,
#  'Great Pyrenees/Australian Cattle Dog': 1,
#  'Rottweiler/Rhod Ridgeback': 1,
#  'Beagle/Whippet': 1,
#  'German Shepherd/Great Pyrenees': 1,
#  'Jack Russell Terrier/Unknown': 1,
#  'Basset Hound/Dachshund': 1,
#  ...}

# %% [markdown]
# #### Пол
#
# Пола, как мы видим, четыре: стерилизованные и нестерилизованные самки и самцы. Также пол может быть неизвестен.

# %%
df_train["SexuponOutcome"].value_counts()
# Out:
# Neutered Male    6802
# Spayed Female    6223
# Intact Female    2466
# Intact Male      2438
# Unknown           780
# Name: SexuponOutcome, dtype: int64

# %% [markdown]
# #####  OrdinalEncoder
#
# Здесь я уже воспользуюсь OneHotEncoder, потому что мы сгенерируем не очень много признаков, как в случае с породой.

# %%
ordinal_encoder = OrdinalEncoder(
    handle_unknown="use_encoded_value", unknown_value=-1)
ordinal_encoder.fit(df_train[["AnimalType", "Color"]])
ordinal_encoder.transform(df_train[["AnimalType", "Color"]])
# Out:
# array([[  0.,  36.],
#        [  0., 270.],
#        [  1., 320.],
#        ...,
#        [  1., 293.],
#        [  1.,   4.],
#        [  0.,   4.]])

# %% [markdown]
# ### Единая матрица признаков

# %%
def prepare_features(df, animal_encoder=None, sex_encoder=None, color_encoder=None, scaler=None):

    columns_categorical = ["AnimalType", "SexuponOutcome", 'Breed']
    date_age_columns = ["DateTime", "AgeuponOutcome"]

    dt = pandas_dates2number(df["DateTime"])
    age = pandas_ages2number(df["AgeuponOutcome"])

    date_age_features = pd.concat([dt, age], axis=1)

    if animal_encoder is None and sex_encoder is None and color_encoder is None and scaler is None:
        animal_encoder = LabelEncoder()

        animal_encoder.fit(df["AnimalType"])

        sex_encoder = LabelEncoder()
        sex_encoder.fit(df["SexuponOutcome"])

        color_encoder = CountVectorizer()
        color_encoder.fit(df["Color"])
        
        scaler = StandardScaler()
        scaler.fit(date_age_features)
        
    date_age_features =  scaler.transform(date_age_features)
            
    animal_feature = animal_encoder.transform(df["AnimalType"])

    sex_feature = sex_encoder.transform(df["SexuponOutcome"])
    
    breed_feature = df["Breed"].apply(lambda x: my_breeds_encoder[x] if x in my_breeds_encoder.keys() else 0)

    color_features = color_encoder.transform(df["Color"])

    color_feature_names = color_encoder.get_feature_names()

    X = sparse.hstack([animal_feature[:, np.newaxis], sex_feature[:,
                      np.newaxis], breed_feature[:, np.newaxis], color_features,  date_age_features])

    return X, list(columns_categorical) + list(color_feature_names) + date_age_columns, animal_encoder, sex_encoder, color_encoder, scaler

# %%
X_train, fnames, animal_encoder, sex_encoder, color_encoder, scaler = prepare_features(df_train)
y_train = df_train["Outcome"]
X_test, _, _, _, _, _ = prepare_features(df_test, animal_encoder, sex_encoder, color_encoder, scaler)

X_train.shape, X_test.shape, np.array(fnames)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\User\AppData\Local\Temp\ipykernel_17012\1833675630.py:38: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   np.newaxis], breed_feature[:, np.newaxis], color_features,  date_age_features])
# c:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# C:\Users\User\AppData\Local\Temp\ipykernel_17012\1833675630.py:38: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   np.newaxis], breed_feature[:, np.newaxis], color_features,  date_age_features])
# ((18710, 41),
#  (8019, 41),
#  array(['AnimalType', 'SexuponOutcome', 'Breed', 'agouti', 'apricot',
#         'black', 'blue', 'brindle', 'brown', 'buff', 'calico', 'chocolate',
#         'cream', 'fawn', 'flame', 'gold', 'gray', 'lilac', 'liver', 'lynx',
#         'merle', 'orange', 'pink', 'point', 'red', 'ruddy', 'sable',
#         'seal', 'silver', 'smoke', 'tabby', 'tan', 'tick', 'tiger',
#         'torbie', 'tortie', 'tricolor', 'white', 'yellow', 'DateTime',
#         'AgeuponOutcome'], dtype='<U14'))

# %% [markdown]
# ## Сетка параметров
#
# Min_samples_leaf и min_samples_split очень сильно связаны, поэтому я решил, что разумно перебирать только один из них, я взял min_samples_split.
#
# Очень естественно перебирать количество деревьев в лесе решений, поэтому мы перебираем с шагом 50 от 50 до 250, это кажется разумно.
#
# Также перебираем глубину дерева, после пары запусков стало понятно, что оптимально значение явно не меньше 10, но и не очень большое, поэтому я перебираю от 14 до 32.
#
# Технически конечно можно перебирать критерий, но у меня опять же на паре запусков стало видно, что критерий gini работает на порядок лучше, так что я решил воспользоваться рекомендацией sklearn.

# %%
param_grid = [
    {
        "min_samples_split": range(2, 7, 2),
        "max_depth": range(14, 34, 2),
        "n_estimators": [50, 100, 150, 200, 250]}]

param_grid
# Out:
# [{'min_samples_split': range(2, 7, 2),
#   'max_depth': range(14, 34, 2),
#   'n_estimators': [50, 100, 150, 200, 250]}]

# %% [markdown]
# ## Обучение и предсказание

# %%
clf = GridSearchCV(RandomForestClassifier(random_state=0, class_weight="balanced", min_samples_leaf=2),
                    param_grid,
                    scoring=score,
                    verbose=1,
                    n_jobs=-1,
                    cv=StratifiedKFold(n_splits=FOLD_K, random_state=0, shuffle=True))

# %time clf.fit(X_train, y_train)

print("Best params on dev set:")
print(clf.best_params_)
print(clf.best_score_)

print("Scores on development set:")
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']

for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))

best_estimator = clf.best_estimator_
best_estimator.fit(X_train, y_train)

y_pred = best_estimator.predict(X_test)
pd.DataFrame({"ID": df_test["ID"], "Outcome": y_pred}).to_csv(
    "submission_simple_" + score + ".csv", index=None)
# Out:
# Fitting 4 folds for each of 150 candidates, totalling 600 fits
# Wall time: 12min 3s
# Best params on dev set:
# {'max_depth': 28, 'min_samples_split': 2, 'n_estimators': 200}
# 0.44255217077108777
# Scores on development set:
# 0.429 (+/-0.008) for {'max_depth': 14, 'min_samples_split': 2, 'n_estimators': 50}
# 0.428 (+/-0.009) for {'max_depth': 14, 'min_samples_split': 2, 'n_estimators': 100}
# 0.430 (+/-0.003) for {'max_depth': 14, 'min_samples_split': 2, 'n_estimators': 150}
# 0.431 (+/-0.006) for {'max_depth': 14, 'min_samples_split': 2, 'n_estimators': 200}
# 0.429 (+/-0.005) for {'max_depth': 14, 'min_samples_split': 2, 'n_estimators': 250}
# 0.429 (+/-0.008) for {'max_depth': 14, 'min_samples_split': 4, 'n_estimators': 50}
# 0.428 (+/-0.009) for {'max_depth': 14, 'min_samples_split': 4, 'n_estimators': 100}
# 0.430 (+/-0.003) for {'max_depth': 14, 'min_samples_split': 4, 'n_estimators': 150}
# 0.431 (+/-0.006) for {'max_depth': 14, 'min_samples_split': 4, 'n_estimators': 200}
# 0.429 (+/-0.005) for {'max_depth': 14, 'min_samples_split': 4, 'n_estimators': 250}
# 0.430 (+/-0.005) for {'max_depth': 14, 'min_samples_split': 6, 'n_estimators': 50}
# 0.427 (+/-0.005) for {'max_depth': 14, 'min_samples_split': 6, 'n_estimators': 100}
# 0.429 (+/-0.007) for {'max_depth': 14, 'min_samples_split': 6, 'n_estimators': 150}
# 0.428 (+/-0.007) for {'max_depth': 14, 'min_samples_split': 6, 'n_estimators': 200}
# 0.429 (+/-0.004) for {'max_depth': 14, 'min_samples_split': 6, 'n_estimators': 250}
# 0.430 (+/-0.008) for {'max_depth': 16, 'min_samples_split': 2, 'n_estimators': 50}
# 0.431 (+/-0.006) for {'max_depth': 16, 'min_samples_split': 2, 'n_estimators': 100}
# 0.432 (+/-0.003) for {'max_depth': 16, 'min_samples_split': 2, 'n_estimators': 150}
# 0.433 (+/-0.005) for {'max_depth': 16, 'min_samples_split': 2, 'n_estimators': 200}
# 0.432 (+/-0.008) for {'max_depth': 16, 'min_samples_split': 2, 'n_estimators': 250}
# 0.430 (+/-0.008) for {'max_depth': 16, 'min_samples_split': 4, 'n_estimators': 50}
# 0.431 (+/-0.006) for {'max_depth': 16, 'min_samples_split': 4, 'n_estimators': 100}
# 0.432 (+/-0.003) for {'max_depth': 16, 'min_samples_split': 4, 'n_estimators': 150}
# 0.433 (+/-0.005) for {'max_depth': 16, 'min_samples_split': 4, 'n_estimators': 200}
# 0.432 (+/-0.008) for {'max_depth': 16, 'min_samples_split': 4, 'n_estimators': 250}
# 0.428 (+/-0.007) for {'max_depth': 16, 'min_samples_split': 6, 'n_estimators': 50}
# 0.434 (+/-0.008) for {'max_depth': 16, 'min_samples_split': 6, 'n_estimators': 100}
# 0.435 (+/-0.001) for {'max_depth': 16, 'min_samples_split': 6, 'n_estimators': 150}
# 0.435 (+/-0.004) for {'max_depth': 16, 'min_samples_split': 6, 'n_estimators': 200}
# 0.434 (+/-0.002) for {'max_depth': 16, 'min_samples_split': 6, 'n_estimators': 250}
# 0.432 (+/-0.007) for {'max_depth': 18, 'min_samples_split': 2, 'n_estimators': 50}
# 0.433 (+/-0.003) for {'max_depth': 18, 'min_samples_split': 2, 'n_estimators': 100}
# 0.432 (+/-0.006) for {'max_depth': 18, 'min_samples_split': 2, 'n_estimators': 150}
# 0.434 (+/-0.005) for {'max_depth': 18, 'min_samples_split': 2, 'n_estimators': 200}
# 0.434 (+/-0.007) for {'max_depth': 18, 'min_samples_split': 2, 'n_estimators': 250}
# 0.432 (+/-0.007) for {'max_depth': 18, 'min_samples_split': 4, 'n_estimators': 50}
# 0.433 (+/-0.003) for {'max_depth': 18, 'min_samples_split': 4, 'n_estimators': 100}
# 0.432 (+/-0.006) for {'max_depth': 18, 'min_samples_split': 4, 'n_estimators': 150}
# 0.434 (+/-0.005) for {'max_depth': 18, 'min_samples_split': 4, 'n_estimators': 200}
# 0.434 (+/-0.007) for {'max_depth': 18, 'min_samples_split': 4, 'n_estimators': 250}
# 0.432 (+/-0.014) for {'max_depth': 18, 'min_samples_split': 6, 'n_estimators': 50}
# 0.435 (+/-0.013) for {'max_depth': 18, 'min_samples_split': 6, 'n_estimators': 100}
# 0.435 (+/-0.012) for {'max_depth': 18, 'min_samples_split': 6, 'n_estimators': 150}
# 0.437 (+/-0.010) for {'max_depth': 18, 'min_samples_split': 6, 'n_estimators': 200}
# 0.436 (+/-0.007) for {'max_depth': 18, 'min_samples_split': 6, 'n_estimators': 250}
# 0.435 (+/-0.004) for {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 50}
# 0.442 (+/-0.005) for {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 100}
# 0.439 (+/-0.008) for {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 150}
# 0.438 (+/-0.012) for {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 200}
# 0.438 (+/-0.012) for {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 250}
# 0.435 (+/-0.004) for {'max_depth': 20, 'min_samples_split': 4, 'n_estimators': 50}
# 0.442 (+/-0.005) for {'max_depth': 20, 'min_samples_split': 4, 'n_estimators': 100}
# 0.439 (+/-0.008) for {'max_depth': 20, 'min_samples_split': 4, 'n_estimators': 150}
# 0.438 (+/-0.012) for {'max_depth': 20, 'min_samples_split': 4, 'n_estimators': 200}
# 0.438 (+/-0.012) for {'max_depth': 20, 'min_samples_split': 4, 'n_estimators': 250}
# 0.436 (+/-0.010) for {'max_depth': 20, 'min_samples_split': 6, 'n_estimators': 50}
# 0.434 (+/-0.009) for {'max_depth': 20, 'min_samples_split': 6, 'n_estimators': 100}
# 0.435 (+/-0.008) for {'max_depth': 20, 'min_samples_split': 6, 'n_estimators': 150}
# 0.434 (+/-0.009) for {'max_depth': 20, 'min_samples_split': 6, 'n_estimators': 200}
# 0.438 (+/-0.004) for {'max_depth': 20, 'min_samples_split': 6, 'n_estimators': 250}
# 0.436 (+/-0.010) for {'max_depth': 22, 'min_samples_split': 2, 'n_estimators': 50}
# 0.438 (+/-0.006) for {'max_depth': 22, 'min_samples_split': 2, 'n_estimators': 100}
# 0.438 (+/-0.004) for {'max_depth': 22, 'min_samples_split': 2, 'n_estimators': 150}
# 0.439 (+/-0.009) for {'max_depth': 22, 'min_samples_split': 2, 'n_estimators': 200}
# 0.439 (+/-0.009) for {'max_depth': 22, 'min_samples_split': 2, 'n_estimators': 250}
# 0.436 (+/-0.010) for {'max_depth': 22, 'min_samples_split': 4, 'n_estimators': 50}
# 0.438 (+/-0.006) for {'max_depth': 22, 'min_samples_split': 4, 'n_estimators': 100}
# 0.438 (+/-0.004) for {'max_depth': 22, 'min_samples_split': 4, 'n_estimators': 150}
# 0.439 (+/-0.009) for {'max_depth': 22, 'min_samples_split': 4, 'n_estimators': 200}
# 0.439 (+/-0.009) for {'max_depth': 22, 'min_samples_split': 4, 'n_estimators': 250}
# 0.430 (+/-0.007) for {'max_depth': 22, 'min_samples_split': 6, 'n_estimators': 50}
# 0.434 (+/-0.010) for {'max_depth': 22, 'min_samples_split': 6, 'n_estimators': 100}
# 0.436 (+/-0.006) for {'max_depth': 22, 'min_samples_split': 6, 'n_estimators': 150}
# 0.436 (+/-0.006) for {'max_depth': 22, 'min_samples_split': 6, 'n_estimators': 200}
# 0.436 (+/-0.007) for {'max_depth': 22, 'min_samples_split': 6, 'n_estimators': 250}
# 0.437 (+/-0.005) for {'max_depth': 24, 'min_samples_split': 2, 'n_estimators': 50}
# 0.441 (+/-0.005) for {'max_depth': 24, 'min_samples_split': 2, 'n_estimators': 100}
# 0.439 (+/-0.009) for {'max_depth': 24, 'min_samples_split': 2, 'n_estimators': 150}
# 0.439 (+/-0.013) for {'max_depth': 24, 'min_samples_split': 2, 'n_estimators': 200}
# 0.441 (+/-0.009) for {'max_depth': 24, 'min_samples_split': 2, 'n_estimators': 250}
# 0.437 (+/-0.005) for {'max_depth': 24, 'min_samples_split': 4, 'n_estimators': 50}
# 0.441 (+/-0.005) for {'max_depth': 24, 'min_samples_split': 4, 'n_estimators': 100}
# 0.439 (+/-0.009) for {'max_depth': 24, 'min_samples_split': 4, 'n_estimators': 150}
# 0.439 (+/-0.013) for {'max_depth': 24, 'min_samples_split': 4, 'n_estimators': 200}
# 0.441 (+/-0.009) for {'max_depth': 24, 'min_samples_split': 4, 'n_estimators': 250}
# 0.432 (+/-0.010) for {'max_depth': 24, 'min_samples_split': 6, 'n_estimators': 50}
# 0.435 (+/-0.006) for {'max_depth': 24, 'min_samples_split': 6, 'n_estimators': 100}
# 0.434 (+/-0.010) for {'max_depth': 24, 'min_samples_split': 6, 'n_estimators': 150}
# 0.436 (+/-0.009) for {'max_depth': 24, 'min_samples_split': 6, 'n_estimators': 200}
# 0.435 (+/-0.004) for {'max_depth': 24, 'min_samples_split': 6, 'n_estimators': 250}
# 0.438 (+/-0.002) for {'max_depth': 26, 'min_samples_split': 2, 'n_estimators': 50}
# 0.438 (+/-0.006) for {'max_depth': 26, 'min_samples_split': 2, 'n_estimators': 100}
# 0.440 (+/-0.005) for {'max_depth': 26, 'min_samples_split': 2, 'n_estimators': 150}
# 0.439 (+/-0.007) for {'max_depth': 26, 'min_samples_split': 2, 'n_estimators': 200}
# 0.440 (+/-0.004) for {'max_depth': 26, 'min_samples_split': 2, 'n_estimators': 250}
# 0.438 (+/-0.002) for {'max_depth': 26, 'min_samples_split': 4, 'n_estimators': 50}
# 0.438 (+/-0.006) for {'max_depth': 26, 'min_samples_split': 4, 'n_estimators': 100}
# 0.440 (+/-0.005) for {'max_depth': 26, 'min_samples_split': 4, 'n_estimators': 150}
# 0.439 (+/-0.007) for {'max_depth': 26, 'min_samples_split': 4, 'n_estimators': 200}
# 0.440 (+/-0.004) for {'max_depth': 26, 'min_samples_split': 4, 'n_estimators': 250}
# 0.432 (+/-0.002) for {'max_depth': 26, 'min_samples_split': 6, 'n_estimators': 50}
# 0.436 (+/-0.004) for {'max_depth': 26, 'min_samples_split': 6, 'n_estimators': 100}
# 0.436 (+/-0.009) for {'max_depth': 26, 'min_samples_split': 6, 'n_estimators': 150}
# 0.437 (+/-0.008) for {'max_depth': 26, 'min_samples_split': 6, 'n_estimators': 200}
# 0.438 (+/-0.008) for {'max_depth': 26, 'min_samples_split': 6, 'n_estimators': 250}
# 0.435 (+/-0.013) for {'max_depth': 28, 'min_samples_split': 2, 'n_estimators': 50}
# 0.441 (+/-0.008) for {'max_depth': 28, 'min_samples_split': 2, 'n_estimators': 100}
# 0.442 (+/-0.008) for {'max_depth': 28, 'min_samples_split': 2, 'n_estimators': 150}
# 0.443 (+/-0.007) for {'max_depth': 28, 'min_samples_split': 2, 'n_estimators': 200}
# 0.438 (+/-0.010) for {'max_depth': 28, 'min_samples_split': 2, 'n_estimators': 250}
# 0.435 (+/-0.013) for {'max_depth': 28, 'min_samples_split': 4, 'n_estimators': 50}
# 0.441 (+/-0.008) for {'max_depth': 28, 'min_samples_split': 4, 'n_estimators': 100}
# 0.442 (+/-0.008) for {'max_depth': 28, 'min_samples_split': 4, 'n_estimators': 150}
# 0.443 (+/-0.007) for {'max_depth': 28, 'min_samples_split': 4, 'n_estimators': 200}
# 0.438 (+/-0.010) for {'max_depth': 28, 'min_samples_split': 4, 'n_estimators': 250}
# 0.431 (+/-0.007) for {'max_depth': 28, 'min_samples_split': 6, 'n_estimators': 50}
# 0.435 (+/-0.011) for {'max_depth': 28, 'min_samples_split': 6, 'n_estimators': 100}
# 0.434 (+/-0.008) for {'max_depth': 28, 'min_samples_split': 6, 'n_estimators': 150}
# 0.436 (+/-0.009) for {'max_depth': 28, 'min_samples_split': 6, 'n_estimators': 200}
# 0.436 (+/-0.007) for {'max_depth': 28, 'min_samples_split': 6, 'n_estimators': 250}
# 0.434 (+/-0.010) for {'max_depth': 30, 'min_samples_split': 2, 'n_estimators': 50}
# 0.433 (+/-0.008) for {'max_depth': 30, 'min_samples_split': 2, 'n_estimators': 100}
# 0.437 (+/-0.006) for {'max_depth': 30, 'min_samples_split': 2, 'n_estimators': 150}
# 0.437 (+/-0.007) for {'max_depth': 30, 'min_samples_split': 2, 'n_estimators': 200}
# 0.439 (+/-0.008) for {'max_depth': 30, 'min_samples_split': 2, 'n_estimators': 250}
# 0.434 (+/-0.010) for {'max_depth': 30, 'min_samples_split': 4, 'n_estimators': 50}
# 0.433 (+/-0.008) for {'max_depth': 30, 'min_samples_split': 4, 'n_estimators': 100}
# 0.437 (+/-0.006) for {'max_depth': 30, 'min_samples_split': 4, 'n_estimators': 150}
# 0.437 (+/-0.007) for {'max_depth': 30, 'min_samples_split': 4, 'n_estimators': 200}
# 0.439 (+/-0.008) for {'max_depth': 30, 'min_samples_split': 4, 'n_estimators': 250}
# 0.428 (+/-0.005) for {'max_depth': 30, 'min_samples_split': 6, 'n_estimators': 50}
# 0.432 (+/-0.008) for {'max_depth': 30, 'min_samples_split': 6, 'n_estimators': 100}
# 0.432 (+/-0.005) for {'max_depth': 30, 'min_samples_split': 6, 'n_estimators': 150}
# 0.438 (+/-0.010) for {'max_depth': 30, 'min_samples_split': 6, 'n_estimators': 200}
# 0.435 (+/-0.004) for {'max_depth': 30, 'min_samples_split': 6, 'n_estimators': 250}
# 0.434 (+/-0.010) for {'max_depth': 32, 'min_samples_split': 2, 'n_estimators': 50}
# 0.434 (+/-0.009) for {'max_depth': 32, 'min_samples_split': 2, 'n_estimators': 100}
# 0.437 (+/-0.005) for {'max_depth': 32, 'min_samples_split': 2, 'n_estimators': 150}
# 0.436 (+/-0.005) for {'max_depth': 32, 'min_samples_split': 2, 'n_estimators': 200}
# 0.438 (+/-0.009) for {'max_depth': 32, 'min_samples_split': 2, 'n_estimators': 250}
# 0.434 (+/-0.010) for {'max_depth': 32, 'min_samples_split': 4, 'n_estimators': 50}
# 0.434 (+/-0.009) for {'max_depth': 32, 'min_samples_split': 4, 'n_estimators': 100}
# 0.437 (+/-0.005) for {'max_depth': 32, 'min_samples_split': 4, 'n_estimators': 150}
# 0.436 (+/-0.005) for {'max_depth': 32, 'min_samples_split': 4, 'n_estimators': 200}
# 0.438 (+/-0.009) for {'max_depth': 32, 'min_samples_split': 4, 'n_estimators': 250}
# 0.429 (+/-0.011) for {'max_depth': 32, 'min_samples_split': 6, 'n_estimators': 50}
# 0.431 (+/-0.009) for {'max_depth': 32, 'min_samples_split': 6, 'n_estimators': 100}
# 0.434 (+/-0.010) for {'max_depth': 32, 'min_samples_split': 6, 'n_estimators': 150}
# 0.435 (+/-0.012) for {'max_depth': 32, 'min_samples_split': 6, 'n_estimators': 200}
# 0.434 (+/-0.004) for {'max_depth': 32, 'min_samples_split': 6, 'n_estimators': 250}

# %% [markdown]
# Данное решение имеет Score: 0.43413 на Kaggle.

# %% [markdown]
# ### Бонус: поверхностный анализ обученной модели

# %%
eli5.explain_weights(
    best_estimator, target_names=LABEL2OUTCOME, feature_names=fnames)
# Out:
# Explanation(estimator="RandomForestClassifier(class_weight='balanced', max_depth=28,\n                       min_samples_leaf=2, n_estimators=200, random_state=0)", description='\nRandom forest feature importances; values are numbers 0 <= x <= 1;\nall values sum to 1.\n', error=None, method='feature importances', is_regression=False, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature='AgeuponOutcome', weight=0.26406927897758914, std=0.026600050157469284, value=None), FeatureWeight(feature='DateTime', weight=0.24353994095605325, std=0.017981114324867348, value=None), FeatureWeight(feature='SexuponOutcome', weight=0.16722384577869695, std=0.021544518180051497, value=None), FeatureWeight(feature='Breed', weight=0.10952404115883234, std=0.02433134102063027, value=None), FeatureWeight(feature='AnimalType', weight=0.04321016906100756, std=0.028687875084107733, value=None), FeatureWeight(feature='white', weight=0.027122847189399474, std=0.007301659211635818, value=None), FeatureWeight(feature='black', weight=0.019058870060622856, std=0.005611328038995294, value=None), FeatureWeight(feature='tabby', weight=0.016592316389484395, std=0.010648682097322044, value=None), FeatureWeight(feature='brown', weight=0.01613319210072654, std=0.00549209669687983, value=None), FeatureWeight(feature='blue', weight=0.010699226849804672, std=0.0033891204464054875, value=None), FeatureWeight(feature='tan', weight=0.009391990235094079, std=0.003286963012087385, value=None), FeatureWeight(feature='gray', weight=0.006567395816176966, std=0.003659763951784977, value=None), FeatureWeight(feature='cream', weight=0.006427983335366211, std=0.0031950636555034824, value=None), FeatureWeight(feature='orange', weight=0.005945479651979885, std=0.0029915590857606303, value=None), FeatureWeight(feature='brindle', weight=0.00570442394327059, std=0.0026133703884582008, value=None), FeatureWeight(feature='tortie', weight=0.00466932312119636, std=0.0026156925652861996, value=None), FeatureWeight(feature='point', weight=0.004182907384974076, std=0.0030759738448108637, value=None), FeatureWeight(feature='red', weight=0.0041246508823776775, std=0.0015060682092338628, value=None), FeatureWeight(feature='torbie', weight=0.0035919770636182345, std=0.002416214335414842, value=None), FeatureWeight(feature='calico', weight=0.0035767957075120245, std=0.002186541357016793, value=None)], remaining=21), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)
